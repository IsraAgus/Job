# %% [markdown]
# <div class="alert alert-block alert-info">
#     <img src='twitter.png' width="200" height="200"/>
#     <h1><center>Developers Twitter</center></h1>
#     <p><center>Testing my Twitter API</center></p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3><center>Documentation url: </center></h3>
#     <center><br/><a src=https://tweepy.readthedocs.io/en/latest/install.html>Haz doble click aquí</a></center>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3><center>Imports</center></h3>
# </div>

# %%
import tweepy
from pandas.io.json import json_normalize
import json
import pandas as pd
import random
import csv

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3><center>Methods</center></h3>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3><center>Implementation</center></h3>
# </div>

# %%
consumer_key = 'consumer_key'
consumer_secret = 'consumer_secret'
access_token = 'access_token'
access_token_secret = 'access_token_secret'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)#parser=tweepy.parsers.JSONParser()

public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# El 1 de diciembre de este año quedará consolidado el @INSABI_Mexico, por lo que la atención médica y los medicament… https://t.co/1G4g33uOB8
# Aprobación de #TMEC en #EU, buena noticia para México y socios: Secretaría de Economía https://t.co/TJDuS24GM5 https://t.co/Ds0SriirGU
# Listen to @Lin_Manuel, @billyeichner, @MalcolmJenkins, and @aijenpoo—and commit today to talk to new voters. It's h… https://t.co/3DCTgOaCH5
# @maiteazuela 🎙 "Debemos entender que Alejandro Gertz Manero no atacó como tal los procesos de investigación que lle… https://t.co/BYtlKlbW58
# Súper pónganle a @OficialTuCasaTV para enterarse de todo sobre #CindyLaRegia con @cassandra_sn y @giuseppegamba_. ¡… https://t.co/XwEjXS1dom
# ¡OPORTUNIDAD Y CAPACIDAD EN @Chivas 🐐🤩!
#
# @FerbBeltran se ha consolidado en el Rebaño y ha cobrado relevancia con Lu… https://t.co/xP8TnqWPSe
# De acuerdo con el subsecretario Jesús Seade, la votación fue de 89 a favor y 10 en contra. https://t.co/6indCZqPoy
# ...

# %%
consumer_key = 'consumer_key'
consumer_secret = 'consumer_secret'
access_token = 'access_token'
access_token_secret = 'access_token_secret'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet)
# Out:
# {'created_at': 'Thu Jan 16 17:36:45 +0000 2020', 'id': 1217863273044836354, 'id_str': '1217863273044836354', 'text': 'RT @Farco: Guerrero: Vengaré la muerte de mi hermano!\n\nElfo: Aquí tienes mi arco!\n\nEnano: Aquí tienes mi hacha!\n\nNigromante: Aquí tienes a…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Farco', 'name': 'Farko', 'id': 14382061, 'id_str': '14382061', 'indices': [3, 9]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 720315572718686211, 'id_str': '720315572718686211', 'name': 'Rodrigo 🤖', 'screen_name': 'rodGG013', 'location': 'Ciudad de México', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 63, 'friends_cou
# ...

# %%
# Get the User object for twitter...
user = api.get_user('twitter')

# %%
print(user.screen_name)
print(user.followers_count)
# Out:
# Twitter
# 56944938

# %%
for friend in user.friends():
    print(friend.screen_name)
# Out:
# TwitterRetweets

# %%
api.user_timeline(id="JavBarr")
# Out:
# [{'created_at': 'Fri Sep 27 16:01:46 +0000 2019',
#   'id': 1177614315425275904,
#   'id_str': '1177614315425275904',
#   'text': '“NUESTRA VIDA ES NUESTRO MENSAJE”. Mahatma Gandhi',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 129844775,
#    'id_str': '129844775',
#    'name': 'Javier Barrera',
#    'screen_name': 'JavBarr',
#    'location': '',
#    'description': 'Todos tenemos la obligación de descubrir para qué somos buenos!',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 6958,
#    'friends_count': 503,
#    'listed_count': 0,
# ...

# %%
api.user_timeline(id="realDonaldTrump")
# Out:
# [{'created_at': 'Thu Jan 16 15:59:19 +0000 2020',
#   'id': 1217838753810669568,
#   'id_str': '1217838753810669568',
#   'text': "Amazon Calls 'Profiles in Corruption' the 'Most Anticipated' Nonfiction Book https://t.co/sOQcs3OHS4 via @BreitbartNews",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'BreitbartNews',
#      'name': 'Breitbart News',
#      'id': 457984599,
#      'id_str': '457984599',
#      'indices': [105, 119]}],
#    'urls': [{'url': 'https://t.co/sOQcs3OHS4',
#      'expanded_url': 'http://bit.ly/2tlBT7y',
#      'display_url': 'bit.ly/2tlBT7y',
#      'indices': [77, 100]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
# ...

# %%
api.user_timeline(id="CarmenSalinasLo")
# Out:
# [{'created_at': 'Thu Jan 16 04:17:17 +0000 2020',
#   'id': 1217662078065897473,
#   'id_str': '1217662078065897473',
#   'text': 'RT @CarmenSalinasLo: Ella es mi adorada hija. María Eugenia Plascencia Salinas y mi yerno querido José Manuel MONGE Chulia hoy hace 32 años…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'CarmenSalinasLo',
#      'name': 'Carmen Salinas',
#      'id': 445743209,
#      'id_str': '445743209',
#      'indices': [3, 19]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 445743209,
#    'id_str': '445743209',
#    'name': 'Carmen Salinas',
#    'screen_name': 'CarmenSalinasLo',
#    'location': '',
# ...

# %%
data = api.user_timeline(id="JavBarr")

# %%
i = 0
for element in data:
    print(element['text'],i)
    i += 1
# Out:
# “NUESTRA VIDA ES NUESTRO MENSAJE”. Mahatma Gandhi 0
# El alumno preguntó: profesor, cuál es el tiempo verbal más difícil? Olvidar, respondió el profesor. 1
# @FierroGossman Increíble entrevista Julieta, gracias por compartir tanta sabiduría. 2
# Si te cuesta tu paz, es demasiado caro.
# Via @RosauraRo 3
# “Si tú crees que puedes estás en lo correcto, y si crees que no, también lo estás.”
# Henry Ford 4
# Coincido. https://t.co/nahWl7kL8v 5
# Vía @RosauraRodriguez https://t.co/VpqcAcuPnv 6
# https://t.co/TNkKr6pkbc 7
# Via @luisvalls1959 https://t.co/CphWc6LRvz 8
# Coincido. Ustedes? https://t.co/bOVqynV6Rl 9
# "La palabra tiene mucho de aritmética: divide cuando se utiliza como navaja, para lesionar; resta cuando se usa con… https://t.co/BMrrPeKNB2 10
# Yo no tengo tiempo para la gente que no tiene tiempo. Vía @RosauraRo 11
# Si no te gusta lo que cosechas, cambia lo que siembras. 12
# Estás tomando algo para el dolor?
# Sí. Distancia. 13
# ...

# %%
type(data[0])
# Out:
# dict

# %%
pd.DataFrame.from_dict(data[0])
# Out:
#                                                         created_at  \
# hashtags                            Fri Sep 27 16:01:46 +0000 2019
# symbols                             Fri Sep 27 16:01:46 +0000 2019
# user_mentions                       Fri Sep 27 16:01:46 +0000 2019
# urls                                Fri Sep 27 16:01:46 +0000 2019
# id                                  Fri Sep 27 16:01:46 +0000 2019
# id_str                              Fri Sep 27 16:01:46 +0000 2019
# name                                Fri Sep 27 16:01:46 +0000 2019
# screen_name                         Fri Sep 27 16:01:46 +0000 2019
# location                            Fri Sep 27 16:01:46 +0000 2019
# description                         Fri Sep 27 16:01:46 +0000 2019
# url                                 Fri Sep 27 16:01:46 +0000 2019
# entities                            Fri Sep 27 16:01:46 +0000 2019
# protected                           Fri Sep 27 16:01:46 +0000 2019
# ...

# %%
json_str
# Out:
# '{"created_at": "Fri Sep 27 16:01:46 +0000 2019", "id": 1177614315425275904, "id_str": "1177614315425275904", "text": "\\u201cNUESTRA VIDA ES NUESTRO MENSAJE\\u201d. Mahatma Gandhi", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [], "urls": []}, "source": "<a href=\\"http://twitter.com/download/iphone\\" rel=\\"nofollow\\">Twitter for iPhone</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 129844775, "id_str": "129844775", "name": "Javier Barrera", "screen_name": "JavBarr", "location": "", "description": "Todos tenemos la obligaci\\u00f3n de descubrir para qu\\u00e9 somos buenos!", "url": null, "entities": {"description": {"urls": []}}, "protected": false, "followers_count": 6959, "friends_count": 504, "listed_count": 25, "created_at": "Mon Apr 05 15:52:01 +0000 2010", "favourites_count": 2477, "utc_offset": null, "tim
# ...

# %%
api.trends_available()
# Out:
# [{'name': 'Worldwide',
#   'placeType': {'code': 19, 'name': 'Supername'},
#   'url': 'http://where.yahooapis.com/v1/place/1',
#   'parentid': 0,
#   'country': '',
#   'woeid': 1,
#   'countryCode': None},
#  {'name': 'Winnipeg',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2972',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 2972,
#   'countryCode': 'CA'},
#  {'name': 'Ottawa',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3369',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 3369,
#   'countryCode': 'CA'},
#  {'name': 'Quebec',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3444',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 3444,
#   'countryCode': 'CA'},
#  {'name': 'Montreal',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3534',
# ...

# %%
"""{'name': 'Mexico',
  'placeType': {'code': 12, 'name': 'Country'},
  'url': 'http://where.yahooapis.com/v1/place/23424900',
  'parentid': 1,
  'country': 'Mexico',
  'woeid': 23424900,
  'countryCode': 'MX'},"""
api.trends_place(23424900)
# Out:
# [{'trends': [{'name': '#iHeartAwards',
#     'url': 'http://twitter.com/search?q=%23iHeartAwards',
#     'promoted_content': None,
#     'query': '%23iHeartAwards',
#     'tweet_volume': 1033640},
#    {'name': 'Noroña',
#     'url': 'http://twitter.com/search?q=Noro%C3%B1a',
#     'promoted_content': None,
#     'query': 'Noro%C3%B1a',
#     'tweet_volume': None},
#    {'name': '#FelizMiercoles',
#     'url': 'http://twitter.com/search?q=%23FelizMiercoles',
#     'promoted_content': None,
#     'query': '%23FelizMiercoles',
#     'tweet_volume': 54460},
#    {'name': 'ECNSE GLAAD 2020',
#     'url': 'http://twitter.com/search?q=%22ECNSE+GLAAD+2020%22',
#     'promoted_content': None,
#     'query': '%22ECNSE+GLAAD+2020%22',
#     'tweet_volume': 45514},
#    {'name': '#PromoCaliente',
#     'url': 'http://twitter.com/search?q=%23PromoCaliente',
#     'promoted_content': None,
#     'query': '%23PromoCaliente',
#     'tweet_volume': None},
#    {'name': 'Valencia',
# ...

# %%
tweepy.Cursor(api.user_timeline, id="JavBarr")

# %%
profiles = pd.read_excel("Profile.xlsx")
profiles[['http','_','url','usr']] = profiles.ID.str.split('/',expand=True)
profiles
# Out:
#                                       ID   http _           url  \
# 0     http://twitter.com/Miguel_Guzman10  http:     twitter.com
# 1      http://twitter.com/LaotraAnaPaula  http:     twitter.com
# 2        http://twitter.com/ivethmurueta  http:     twitter.com
# 3        http://twitter.com/maji19830705  http:     twitter.com
# 4             http://twitter.com/valuric  http:     twitter.com
# ...                                  ...    ... ..          ...
# 1275          http://twitter.com/tana_sp  http:     twitter.com
# 1276       http://twitter.com/charlyrcrh  http:     twitter.com
# 1277       http://twitter.com/marcelaymr  http:     twitter.com
# 1278        http://twitter.com/lfluevano  http:     twitter.com
# 1279          http://twitter.com/Rexiwen  http:     twitter.com
#
#                   usr
# 0     Miguel_Guzman10
# 1      LaotraAnaPaula
# 2        ivethmurueta
# 3        maji19830705
# 4             valuric
# ...               ...
# 1275          tana_sp
# ...

# %%
usrs=list(profiles.usr)

# %%
data = api.user_timeline(id="JavBarr")
# Out:
# 1187

# %%
comments = {'usuario':[],
            'comentarios':[]}
df_coments = pd.DataFrame(comments)
for i in range(40):    
    try:
        data = api.user_timeline(id=usrs[i])
        for element in data:
            dicc = {'usuario':usrs[i],
                    'comentarios':element['text']}
            #print(dicc)
            df_coments = df_coments.append(dicc,ignore_index = True)
            #print(df_coments)
    except:
        dicc = {'usuario':usrs[i],
                'comentarios':"Not authorized."}
        #print(dicc)
        df_coments = df_coments.append(dicc,ignore_index = True)
        #print(df_coments)

# %%
df_coments
# Out:
#              usuario                                        comentarios
# 0    Miguel_Guzman10                                    Not authorized.
# 1     LaotraAnaPaula                                    Not authorized.
# 2       ivethmurueta                    Siii 👍🏼 https://t.co/lxmfAIOn6e
# 3       ivethmurueta  RT @LaComadree: Cuando Danna Paola dijo: “No h...
# 4       ivethmurueta  RT @ahdobabes: Comparte a esta Danna Paola, pa...
# ..               ...                                                ...
# 523   GuerreroUlises          Bueno un selfie 🤳 https://t.co/25aT9Iu7NL
# 524   GuerreroUlises                       @Adonis___01 Que creativos 😊
# 525   GuerreroUlises  RT @GuerreroUlises: Feliz año 2020 🎆🙌🏻💕 https:...
# 526   GuerreroUlises        Feliz año 2020 🎆🙌🏻💕 https://t.co/jXlyFJcpvI
# 527   GuerreroUlises  RT @GuerreroUlises: Beneficios de la Hormona d...
#
# [528 rows x 2 columns]

# %%
df_coments.to_csv("comentarios_pipe.csv",sep='|',quoting=csv.QUOTE_ALL,index=False,encoding="utf-8-sig")
df_coments.to_csv("comentarios_comma.csv",quoting=csv.QUOTE_ALL,index=False,encoding="utf-8-sig")
